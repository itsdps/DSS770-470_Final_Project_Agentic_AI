# %% [markdown]
# # I. Initialization Code

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Simple imports - no path manipulation needed!
from src.gemini import GeminiClient, generate_content
from src.fnPrompts import simple_prompt, product_prompt_template
from src.fnUtils import render_markdown

print("✓ Imports successful!")
# Out:
# ✓ Imports successful!

# %%
print(simple_prompt())
# print(product_prompt_template('Vacuum cleaner'))
# Out:
# Generate a list of 10 product names for vacuum cleaner.

# %%
# Create a Gemini client
gemini = GeminiClient()
print(f"Using model: {gemini.model}")
# Out:
# Using model: gemini-2.5-flash

# %% [markdown]
# # II.
# ## 1.

# %%
response = gemini.generate(simple_prompt())
render_markdown(response)
# Out:
# > Here are 10 product names for a vacuum cleaner, aiming for a mix of modern, powerful, and evocative options:
# >
# > 1.  **VortexClean** (Implies powerful, cyclonic suction)
# > 2.  **AuraVac** (Suggests a clean, fresh atmosphere)
# > 3.  **SentinelVac** (Evokes a watchful, thorough cleaner)
# > 4.  **WhisperGlide** (Highlights quiet operation and smooth movement)
# > 5.  **ApexClean** (Implies peak performance and ultimate cleanliness)
# > 6.  **SwiftLift** (Focuses on speed and effective dirt removal)
# > 7.  **PristinePro** (Suggests professional-level, immaculate results)
# > 8.  **EcoVac** (Hints at efficiency, perhaps bagless or energy-saving features)
# > 9.  **DeepPurge** (Emphasizes intense, thorough cleaning)
# > 10. **AeroSweep** (Suggests lightness, advanced airflow, and efficient cleaning)

# %% [markdown]
# # III.

# %% [markdown]
# ## 1.
# ### 1.1
# ### 1.2
