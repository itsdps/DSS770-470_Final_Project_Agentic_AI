# %% [markdown]
# # Workflow Pattern: Parallelization with Async/Await
#
# ## 🎯 Objective
# Learn how to implement asynchronous parallelization to execute multiple independent AI tasks concurrently, dramatically reducing total execution time.
#
# ---
#
# ## 🔄 What is Parallelization?
#
# **Parallelization** is an agentic workflow pattern where multiple independent tasks are executed simultaneously rather than sequentially. This pattern is particularly effective for I/O-bound operations like API calls to LLMs.
#
# ### Key Benefits:
# - ⚡ **Speed**: Multiple API calls execute at the same time
# - 💰 **Efficiency**: Better resource utilization
# - 📊 **Scalability**: Handles larger workloads effectively
#
# ---
#
# ## 💡 Common Use Cases
#
# ### 1. **RAG with Query Decomposition**
# Breaking a complex query into sub-queries, running retrievals for each in parallel, and synthesizing the results.
#
# ### 2. **Analyzing Large Documents**
# Dividing the document into sections, summarizing each section in parallel, and then combining the summaries.
#
# ### 3. **Generating Multiple Perspectives**
# Asking multiple LLMs the same question with different persona prompts and aggregating their responses.
#
# ### 4. **Map-Reduce Style Operations**
# Processing data in parallel chunks and reducing results into a final output.
#
# ---
#
# ## 🏗️ Architecture Overview
#
# This notebook demonstrates:
# - **Async/Await Pattern**: Using Python's `asyncio` for concurrent execution
# - **Multiple Expert Agents**: Each agent analyzes a topic from a different perspective
# - **Result Aggregation**: Synthesizing individual outputs into a comprehensive report
#
# ### Workflow Steps:
# 1. 📝 Define multiple independent prompts
# 2. 🚀 Execute all prompts concurrently using `asyncio.gather()`
# 3. ⏱️ Measure execution time savings
# 4. 🔄 Aggregate results into a final synthesis
#
# ---
#
# **Source**: [Agentic Patterns - Philipp Schmid](https://www.philschmid.de/agentic-pattern)

# %%
# ============================================================================
# PARALLEL TASK EXECUTION WITH ASYNC OPENAI
# ============================================================================
# This implementation demonstrates the parallelization pattern using Python's
# asyncio library combined with OpenAI's async client. Multiple LLM calls
# are executed concurrently, significantly reducing total execution time.
# ============================================================================

import asyncio
import time
from openai import AsyncOpenAI
import os
from dotenv import load_dotenv

# Load environment variables (OPENAI_API_KEY)
load_dotenv()

# Initialize the async OpenAI client
# This client supports concurrent API calls using asyncio
openai_client = AsyncOpenAI(api_key=os.getenv("OPENAI_API_KEY"))


async def generate_content(prompt: str, model_name: str = "gpt-4o-mini") -> str:
    """
    Generate content using OpenAI's async API.
    
    This function makes an asynchronous call to OpenAI's chat completions endpoint,
    allowing multiple calls to execute concurrently when used with asyncio.gather().
    
    Args:
        prompt (str): The user prompt to send to the LLM
        model_name (str): The OpenAI model to use (default: "gpt-4o-mini")
    
    Returns:
        str: The generated content from the LLM
    
    Note:
        The 'await' keyword allows other async tasks to execute while waiting
        for the API response, enabling true parallelization.
    """
    # Make async API call to OpenAI
    # Multiple calls to this function can execute simultaneously
    response = await openai_client.chat.completions.create(
        model=model_name,
        messages=[
            {"role": "system", "content": "You are an expert analyst providing concise, well-structured reports."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.7,      # Balanced creativity
        max_tokens=1000       # Sufficient for detailed reports
    )
    
    # Extract and return the generated text
    return response.choices[0].message.content.strip()


async def parallel_tasks(topic: str = "Electric Vehicles (EVs)") -> str:
    """
    Execute multiple expert analysis tasks in parallel and aggregate results.
    
    This function demonstrates the parallelization pattern:
    1. Define multiple independent prompts (different expert perspectives)
    2. Execute all prompts concurrently using asyncio.gather()
    3. Measure time savings compared to sequential execution
    4. Aggregate individual reports into a comprehensive synthesis
    
    Args:
        topic (str): The topic to analyze from multiple perspectives
    
    Returns:
        str: A comprehensive aggregated report synthesizing all expert perspectives
    
    Pattern Benefits:
        - Sequential execution: ~3 API calls × avg_response_time
        - Parallel execution: ~max(individual_response_times)
        - Typical speedup: 2-3x faster for I/O-bound operations
    """
    
    # ========================================================================
    # STEP 1: Define Parallel Tasks
    # ========================================================================
    # Each prompt represents an independent analysis task that can be
    # executed concurrently. The tasks don't depend on each other's results.
    
    prompts = [
        f"As an Economic Analyst, write a concise report on the primary economic impacts of the widespread adoption of {topic}. Focus on job creation, investment trends, and effects on traditional auto and oil industries.",
        
        f"As an Environmental Scientist, write a concise report on the key environmental benefits and challenges associated with {topic}. Consider carbon emissions, battery production/disposal, and electricity grid demands.",
        
        f"As a Policy Advisor, write a concise report summarizing the current government policies, subsidies, and international agreements influencing the market for {topic}."
    ]
    
    print(f"🚀 Starting parallel execution of {len(prompts)} expert analyses...\n")
    
    # ========================================================================
    # STEP 2: Run Tasks Concurrently
    # ========================================================================
    # asyncio.gather() executes all coroutines concurrently and waits for
    # all to complete. This is the key to achieving parallelization.
    
    start_time = time.time()
    
    # Create list of coroutines (tasks that will run concurrently)
    tasks = [generate_content(prompt) for prompt in prompts]
    
    # Execute all tasks in parallel and gather results
    # The 'await' here waits for ALL tasks to complete, but they run simultaneously
    results = await asyncio.gather(*tasks)
    
    end_time = time.time()
    execution_time = end_time - start_time
    
    print(f"⏱️  Time taken: {execution_time:.2f} seconds")
    print(f"📊 Average time per task: {execution_time/len(prompts):.2f} seconds")
    print(f"💡 Sequential execution would have taken: ~{execution_time * 3:.2f} seconds\n")

    # ========================================================================
    # STEP 3: Display Individual Results
    # ========================================================================
    print("=" * 70)
    print("📋 INDIVIDUAL EXPERT REPORTS")
    print("=" * 70 + "\n")
    
    expert_roles = ["Economic Analyst", "Environmental Scientist", "Policy Advisor"]
    for i, result in enumerate(results):
        print(f"┌─ Report from {expert_roles[i]} " + "─" * (70 - len(expert_roles[i]) - 18))
        print(f"│")
        for line in result.split('\n'):
            print(f"│ {line}")
        print(f"└" + "─" * 69)
        print()

    # ========================================================================
    # STEP 4: Aggregate Results into Final Comprehensive Report
    # ========================================================================
    print("=" * 70)
    print("🔄 AGGREGATING RESULTS INTO FINAL REPORT")
    print("=" * 70 + "\n")
    
    # Combine all individual reports for the aggregation prompt
    individual_reports = '\n\n'.join([
        f"Expert Report from {expert_roles[i]}:\n{result}" 
        for i, result in enumerate(results)
    ])

    # Create an aggregation prompt that synthesizes all perspectives
    aggregation_prompt = f"""
You are a senior editor tasked with synthesizing multiple expert reports into a single, cohesive document.

Your task is to create a comprehensive summary report on {topic} that:
1. Has a brief introduction explaining the scope of analysis
2. Synthesizes findings from each domain (economic, environmental, policy)
3. Highlights connections and interactions between different perspectives
4. Concludes with an overall outlook and key takeaways

Here are the expert reports to synthesize:

{individual_reports}

Create a well-structured, comprehensive report that integrates these perspectives.
"""

    # Use OpenAI for the synthesis task
    # This could use a more advanced model if needed
    aggregation_response = await openai_client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a senior editor expert at synthesizing multiple reports into cohesive documents."},
            {"role": "user", "content": aggregation_prompt}
        ],
        temperature=0.7,
        max_tokens=2000  # Higher limit for comprehensive synthesis
    )
    
    return aggregation_response.choices[0].message.content.strip()

# %%
# ============================================================================
# EXECUTE PARALLEL WORKFLOW AND DISPLAY FINAL REPORT
# ============================================================================
# Run the parallel analysis workflow and display the synthesized report
# Note: Use 'await' in Jupyter notebooks to run async functions
# ============================================================================

# Define the topic to analyze
topic = "Electric Vehicles (EVs)"

# Execute the parallel workflow
# This will run all expert analyses concurrently and aggregate results
final_report = await parallel_tasks(topic)

# Display the final comprehensive report
print("=" * 70)
print("📊 FINAL COMPREHENSIVE SYNTHESIZED REPORT")
print("=" * 70)
print()
print(final_report)
print()
print("=" * 70)
print("✅ Analysis complete!")
print("=" * 70)
# Out:
# 🚀 Starting parallel execution of 3 expert analyses...
#
# ⏱️  Time taken: 15.35 seconds
# 📊 Average time per task: 5.12 seconds
# 💡 Sequential execution would have taken: ~46.05 seconds
#
# ======================================================================
# 📋 INDIVIDUAL EXPERT REPORTS
# ======================================================================
#
# ┌─ Report from Economic Analyst ────────────────────────────────────
# │
# │ ### Economic Impacts of Widespread Adoption of Electric Vehicles (EVs)
# │
# │ #### Introduction
# │ The transition to Electric Vehicles (EVs) represents a significant shift in the automotive landscape, with profound economic implications. This report outlines the primary impacts of widespread EV adoption focusing on job creation, investment trends, and effects on traditional auto and oil industries.
# │
# │ #### 1. Job Creation
# │ - **Manufacturing Jobs**: The EV sector is generating new manufacturing jobs, particularly in battery production and assembly. This shift requires a workforce skilled in advanced technologies, leading to the creation of new training programs and vocational opportunities.
# │ - **Infrastructure Development**: The expansion of EV charging infrastructure necessitates jobs in construction, electrical engineering, and maintenance. This includes roles in both public and private sectors.
# │ - **Service Sector Growth**: As EV adoption increases, there is a rise in demand for related services such as maintenance, software development, and customer support, contributing to overall job growth.
# │
# │ #### 2. Investment Trends
# │ - **Increased Capital Investment**: Significant investments are flowing into EV technology, with automakers committing billions toward R&D, battery technology, and production facilities. For instance, major manufacturers have announced plans to build gigafactories, driving local economic growth.
# │ - **Venture Capital**: There is a surge in venture capital funding directed at EV startups, battery technology, and charging solutions. This trend is fostering innovation and competitive dynamics within the automotive sector.
# │ - **Government Incentives**: Policymakers are implementing subsidies and tax incentives to encourage EV adoption, which in turn stimulates investment in renewable energy sources and related technologies.
# │
# │ #### 3. Effects on Traditional Auto and Oil Industries
# │ - **Disruption of Traditional Auto Manufacturing**: Established automotive companies face pressures to transition to EV production, which may disrupt existing supply chains. Traditional manufacturing jobs may decline as companies pivot to new technologies and production processes.
# │ - **Oil Industry Impact**: The shift towards EVs is expected to reduce demand for gasoline and diesel, leading to a potential long-term decline in oil revenues. This could impact economies heavily reliant on fossil fuel extraction and sales.
# │ - **Market Adaptation**: Traditional automakers are investing in EV technology to maintain market share, leading to a period of transformation and potential consolidation within the industry. This adaptation may also result in job losses in fossil fuel-dependent sectors.
# │
# │ #### Conclusion
# │ The widespread adoption of Electric Vehicles presents a mixed economic landscape characterized by job creation in new industries, significant investment opportunities, and challenges for traditional automotive and oil sectors. Policymakers and business leaders must navigate this transition to harness potential benefits while mitigating adverse effects on existing industries. The future of transportation will not only be defined by technological advancements but also by strategic economic adaptations.
# └─────────────────────────────────────────────────────────────────────
#
# ┌─ Report from Environmental Scientist ─────────────────────────────
# │
# │ **Report on the Environmental Benefits and Challenges of Electric Vehicles (EVs)**
# │
# │ **Prepared by:** [Your Name]
# │ **Date:** [Current Date]
# │
# │ ---
# │
# │ ### Introduction
# │ Electric Vehicles (EVs) are increasingly promoted as a sustainable alternative to internal combustion engine vehicles. This report outlines the key environmental benefits and challenges associated with the widespread adoption of EVs, focusing on carbon emissions, battery production and disposal, and electricity grid demands.
# │
# │ ### Key Environmental Benefits
# │
# │ 1. **Reduced Carbon Emissions**
# │    - **Lower Tailpipe Emissions:** EVs produce zero tailpipe emissions, significantly reducing local air pollution and greenhouse gases compared to gasoline and diesel vehicles.
# │    - **Lifecycle Emissions:** When charged with renewable energy, the lifecycle carbon emissions of EVs can be substantially lower than those of conventional vehicles, contributing to climate change mitigation.
# │
# │ 2. **Decreased Fossil Fuel Dependence**
# │    - Transitioning to EVs reduces reliance on fossil fuels for transportation, fostering energy security and promoting the use of renewable energy sources.
# │
# │ 3. **Improved Energy Efficiency**
# │    - EVs convert over 60% of electrical energy from the grid to power at the wheels, whereas conventional gasoline vehicles only convert about 20% of the energy stored in gasoline. This efficiency leads to lower overall energy consumption.
# │
# │ ### Key Environmental Challenges
# │
# │ 1. **Battery Production and Disposal**
# │    - **Resource Extraction:** The production of lithium-ion batteries involves mining for lithium, cobalt, and nickel, which can lead to environmental degradation, water scarcity, and pollution.
# │    - **End-of-Life Management:** Current recycling processes for EV batteries are not fully developed, which raises concerns over hazardous waste and resource recovery. Improper disposal can lead to soil and water contamination.
# │
# │ 2. **Electricity Grid Demands**
# │    - **Increased Demand on Power Infrastructure:** The widespread adoption of EVs could strain existing electricity grids, particularly during peak charging times. This could necessitate upgrades to grid infrastructure and increased generation capacity.
# │    - **Source of Electricity:** The environmental benefits of EVs can be diminished if the electricity used for charging is generated from fossil fuels. The transition to renewable energy sources is crucial to maximizing the benefits of EVs.
# │
# │ 3. **Geographical Disparities**
# │    - The environmental impact of EVs can vary significantly by region, depending on the local energy mix. Areas reliant on coal or oil for electricity may not see the same emissions reduction as those with a cleaner energy portfolio.
# │
# │ ### Conclusion
# │ Electric Vehicles offer significant environmental benefits, primarily in reducing carbon emissions and enhancing energy efficiency. However, challenges related to battery production, disposal, and electricity demand must be addressed to maximize their positive impact. A holistic approach that includes sustainable battery technology, improved recycling processes, and a transition to renewable energy sources is essential for the future of EVs in a sustainable transportation system.
# │
# │ ### Recommendations
# │ - Invest in research and development of sustainable battery technologies and recycling methods.
# │ - Encourage policies that promote the growth of renewable energy sources to power EV charging.
# │ - Upgrade grid infrastructure to accommodate increased demand from EVs while ensuring reliability and efficiency.
# │
# │ ---
# │
# │ **End of Report**
# └─────────────────────────────────────────────────────────────────────
#
# ┌─ Report from Policy Advisor ──────────────────────────────────────
# │
# │ ### Report: Current Government Policies, Subsidies, and International Agreements Influencing the Electric Vehicle Market
# │
# │ **Date:** [Current Date]
# │
# │ **Prepared by:** [Your Name], Policy Advisor
# │
# │ ---
# │
# │ #### 1. Introduction
# │ The electric vehicle (EV) market is significantly influenced by a combination of government policies, financial incentives, and international agreements aimed at promoting sustainability and reducing greenhouse gas emissions. This report summarizes the key elements shaping the EV landscape as of October 2023.
# │
# │ #### 2. Government Policies
# │
# │ - **National Emission Standards:** Many countries have implemented stricter emissions standards for vehicles, incentivizing manufacturers to shift towards EV production. For example, the European Union has set targets to reduce CO2 emissions from new cars by 55% by 2030.
# │
# │ - **Fuel Economy Regulations:** In the U.S., the Corporate Average Fuel Economy (CAFE) regulations are increasingly favoring electric and hybrid vehicles, pushing automakers to enhance their EV offerings.
# │
# │ - **State-Level Initiatives:** In the U.S., states like California have introduced their own ambitious targets for EV adoption, including the goal to sell only zero-emission vehicles by 2035.
# │
# │ #### 3. Subsidies and Incentives
# │
# │ - **Purchase Incentives:** Many governments offer direct subsidies for EV buyers. For instance, the U.S. federal government provides tax credits of up to $7,500 for qualifying electric vehicles, while countries like Norway offer substantial exemptions from VAT and road tolls.
# │
# │ - **Charging Infrastructure Investment:** Governments are investing in EV charging infrastructure. The U.S. has allocated billions through the Infrastructure Investment and Jobs Act to expand charging networks, aiming for widespread accessibility.
# │
# │ - **Manufacturer Incentives:** Some regions provide financial support to manufacturers for EV production, research, and development. The EU’s Green Deal includes funding aimed at facilitating the transition to cleaner vehicle technologies.
# │
# │ #### 4. International Agreements
# │
# │ - **Paris Agreement:** Many nations, as part of their commitments under the Paris Agreement, are adopting policies to accelerate the transition to electric vehicles to meet climate targets.
# │
# │ - **Global EV Partnerships:** Multinational agreements, such as the Global EV Initiative, encourage cooperation on technology sharing, regulatory alignment, and promoting EV adoption across borders.
# │
# │ - **Trade Agreements:** Recent trade agreements have started incorporating clauses that promote green technologies, including electric vehicles, which can affect tariffs and market access for EV manufacturers.
# │
# │ #### 5. Conclusion
# │ The electric vehicle market is currently supported by a robust framework of government policies, financial incentives, and international collaborations that collectively drive EV adoption. As governments continue to prioritize sustainability and emissions reductions, the market is expected to expand further, benefiting from ongoing technological advancements and consumer interest in environmentally friendly transportation.
# │
# │ #### 6. Recommendations
# │ - **Monitor Policy Changes:** Stay informed on evolving government policies and international agreements that may impact the EV market.
# │ - **Engage Stakeholders:** Collaborate with industry leaders, environmental groups, and government entities to align on best practices and innovations.
# │ - **Promote Public Awareness:** Increase efforts to educate consumers about the benefits of EVs and available incentives to stimulate demand.
# │
# │ ---
# │
# │ **End of Report**
# └─────────────────────────────────────────────────────────────────────
#
# ======================================================================
# 🔄 AGGREGATING RESULTS INTO FINAL REPORT
# ======================================================================
#
# ======================================================================
# 📊 FINAL COMPREHENSIVE SYNTHESIZED REPORT
# ======================================================================
#
# # Comprehensive Summary Report on Electric Vehicles (EVs)
#
# ## Introduction
# The transition to Electric Vehicles (EVs) marks a pivotal moment in the automotive industry, intertwining economic, environmental, and policy dimensions. This report synthesizes findings from expert analyses to provide a cohesive overview of the impacts and challenges associated with widespread EV adoption. By examining the economic benefits and disruptions, environmental implications, and policy frameworks, this report aims to articulate a holistic understanding of the evolving landscape of electric mobility.
#
# ## Economic Analysis
#
# ### Job Creation
# The EV sector is catalyzing job growth across multiple domains:
# - **Manufacturing**: A surge in manufacturing jobs is evident, particularly in battery production, requiring specialized skills and prompting new vocational training initiatives.
# - **Infrastructure Development**: The expansion of EV charging networks is creating employment opportunities in construction and engineering, vital for building and maintaining this new infrastructure.
# - **Service Sector**: Increased demand for maintenance and software services related to EVs is contributing to overall service sector growth.
#
# ### Investment Trends
# - **Capital Influx**: Significant investments are being directed towards R&D, battery technology, and the establishment of new production facilities, particularly in gigafactories. This influx is crucial for local economic growth.
# - **Venture Capital**: There is a notable rise in venture capital funding for EV startups, fostering competitive dynamics and innovation within the automotive sector.
# - **Government Subsidies**: The implementation of various subsidies and tax incentives by policymakers serves to stimulate investment in EV technologies and renewable energy sources.
#
# ### Disruption of Traditional Industries
# - Established automotive manufacturers are under pressure to transition to EV production, potentially disrupting traditional supply chains and leading to job losses in some areas.
# - The oil industry faces a long-term decline in revenues as EV adoption reduces fossil fuel demand, impacting economies dependent on oil extraction.
#
# ## Environmental Analysis
#
# ### Key Environmental Benefits
# - **Reduction in Carbon Emissions**: EVs produce zero tailpipe emissions, significantly lowering local air pollutants and greenhouse gas emissions, especially when charged using renewable energy sources.
# - **Decreased Fossil Fuel Dependence**: The transition to EVs promotes energy security and supports the shift towards renewable energy utilization.
# - **Enhanced Energy Efficiency**: EVs demonstrate superior energy conversion efficiency, utilizing over 60% of electrical energy compared to just 20% for conventional vehicles.
#
# ### Environmental Challenges
# - **Battery Production and Disposal**: The extraction of resources for lithium-ion batteries poses environmental risks, including pollution and resource depletion. Furthermore, current recycling processes are insufficient, raising concerns about hazardous waste.
# - **Electricity Grid Strain**: Increased EV adoption may place significant demands on electricity grids, necessitating infrastructure upgrades and a shift towards renewable energy sources.
# - **Local Energy Mix Disparities**: The environmental benefits of EVs can vary by region, heavily dependent on the local energy mix and the sources of electricity generation.
#
# ## Policy Analysis
#
# ### Government Policies
# - **Emission Standards**: Stricter national emission standards are incentivizing manufacturers to produce more EVs, with significant targets set by regions such as the EU and California.
# - **Fuel Economy Regulations**: Regulations like the U.S. Corporate Average Fuel Economy (CAFE) are increasingly favoring electric and hybrid vehicle production.
#
# ### Subsidies and Incentives
# - **Financial Incentives for Purchasers**: Government subsidies, like tax credits in the U.S., encourage consumer adoption of EVs, while exemptions in countries like Norway further stimulate demand.
# - **Infrastructure Investment**: Substantial government investments are being allocated to expand charging networks, ensuring that EV infrastructure keeps pace with adoption rates.
#
# ### International Agreements
# - **Paris Agreement Commitments**: Many countries are aligning their policies with climate commitments, promoting EV adoption as a key strategy for reducing greenhouse gas emissions.
# - **Global Partnerships**: Initiatives like the Global EV Initiative facilitate international cooperation on technology and regulatory standards, enhancing the global EV market's growth.
#
# ## Connections and Interactions
# The interplay between economic, environmental, and policy frameworks is crucial for the successful transition to EVs. Economic investments and job creation in the EV sector are bolstered by supportive government policies and incentives, while the environmental benefits help justify these investments. Conversely, the challenges highlighted in environmental analyses, such as battery production impacts and grid demands, necessitate adaptive policies that can mitigate adverse effects while promoting sustainable practices.
#
# ## Conclusion and Key Takeaways
# The future of transportation is being reshaped by the widespread adoption of Electric Vehicles, presenting a landscape filled with both opportunities and challenges. Key takeaways include:
# - **Economic Opportunity**: EV adoption is poised to create jobs and stimulate investment, but traditional industries must adapt to mitigate potential job losses.
# - **Environmental Imperatives**: While EVs significantly reduce emissions, the sustainability of battery production and electricity sources remains a critical concern.
# - **Policy Alignment**: Strong government policies and international cooperation are essential to foster a conducive environment for EV growth and address associated challenges.
#
# Overall, a collaborative approach involving policymakers, industry leaders, and consumers is vital to navigate this transition effectively, ensuring that the benefits of electric mobility are realized while minimizing its challenges.
#
# ======================================================================
# ✅ Analysis complete!
# ======================================================================
